# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\airlines_flights_data.csv")

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
df.columns
# Out:
# Index(['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.drop(columns ='index',inplace=True)

# %%
df.head(10)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# ...

# %%
df.tail(10)
# Out:
#           airline  flight source_city departure_time stops arrival_time  \
# 300143  Air_India  AI-440     Chennai  Early_Morning   one        Night
# 300144  Air_India  AI-539     Chennai        Evening   one      Morning
# 300145  Air_India  AI-430     Chennai        Morning   one      Morning
# 300146  Air_India  AI-440     Chennai  Early_Morning   one      Morning
# 300147  Air_India  AI-569     Chennai  Early_Morning   one        Night
# 300148    Vistara  UK-822     Chennai        Morning   one      Evening
# 300149    Vistara  UK-826     Chennai      Afternoon   one        Night
# 300150    Vistara  UK-832     Chennai  Early_Morning   one        Night
# 300151    Vistara  UK-828     Chennai  Early_Morning   one      Evening
# 300152    Vistara  UK-822     Chennai        Morning   one      Evening
#
#        destination_city     class  duration  days_left  price
# 300143        Hyderabad  Business     17.42         49  51345
# ...

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
print('\nStatistical Summary:')
df.describe()
# Out:
# Statistical Summary:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %%
df.describe(include='object')
# Out:
#         airline  flight source_city departure_time   stops arrival_time  \
# count    300153  300153      300153         300153  300153       300153
# unique        6    1561           6              6       3            6
# top     Vistara  UK-706       Delhi        Morning     one        Night
# freq     127859    3235       61343          71146  250863        91538
#
#        destination_city    class
# count            300153   300153
# unique                6        2
# top              Mumbai  Economy
# freq              59097   206666

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price]
# Index: []

# %%
sns.heatmap(df.select_dtypes(include = ['number']).corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
df_temp=pd.get_dummies(df,columns=['airline','source_city','departure_time','stops','arrival_time','destination_city','class'])
df_temp.drop(columns=['flight'],inplace=True)
correlations=df_temp.corr()

# %%
top_5_corr = correlations['price'].drop('price').sort_values(ascending=False).head(5)
print("TOP 5 POSITIVELY CORRELATED ATRIBUTES TO PRICE\n",top_5_corr)

lowest_5_corr=correlations['price'].drop('price').sort_values(ascending=False).tail(5)
print("TOP 5 NEGATIVELY CORRELATED ATRIBUTES TO PRICE\n",lowest_5_corr)
# Out:
# TOP 5 POSITIVELY CORRELATED ATRIBUTES TO PRICE
#  class_Business       0.937860
# airline_Vistara      0.360816
# duration             0.204222
# stops_one            0.199913
# airline_Air_India    0.070041
# Name: price, dtype: float64
# TOP 5 NEGATIVELY CORRELATED ATRIBUTES TO PRICE
#  airline_AirAsia    -0.176188
# stops_zero         -0.187277
# airline_GO_FIRST   -0.194179
# airline_Indigo     -0.280882
# class_Economy      -0.937860
# Name: price, dtype: float64

# %%
print("\n Most Expensive Flights ")
print(df.nlargest(5, 'price')[['airline', 'class', 'duration', 'price']])

print("\n Cheapest Flights ")
print(df.nsmallest(5, 'price')[['airline', 'class', 'duration', 'price']])
# Out:
#  Most Expensive Flights
#         airline     class  duration   price
# 261377  Vistara  Business     13.50  123071
# 216096  Vistara  Business     10.92  117307
# 215859  Vistara  Business     21.08  116562
# 277345  Vistara  Business     16.42  115211
# 270999  Vistara  Business      9.50  114705
#
#  Cheapest Flights
#          airline    class  duration  price
# 203807   AirAsia  Economy      1.17   1105
# 203808  GO_FIRST  Economy      1.25   1105
# 203908   AirAsia  Economy      1.17   1105
# 203909  GO_FIRST  Economy      1.25   1105
# 204003   AirAsia  Economy      1.17   1105

# %%
df['route'] = df['source_city'] + " to " + df['destination_city']
top_routes = df['route'].value_counts().head(5)
plt.figure(figsize=(10, 6))
top_routes.plot(kind='barh')
plt.title('Top 5 Busiest Routes')
plt.show()

# %%
df.columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price', 'route'],
#       dtype='object')

# %%
plt.figure(figsize=(24,18))
plt.subplot(3,3,1)
ax=sns.countplot(x=df['stops'],palette='pastel')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution Of The No. Of Stops Of  Flight')

plt.subplot(3,3,2)
ax=sns.countplot(x=df['departure_time'],palette='pastel')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution Of Departure Times for Flight')


plt.subplot(3,3,3)
ax=sns.countplot(x=df['class'],palette='pastel')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution Of Flight Classes ')


plt.subplot(3,3,4)
ax=sns.countplot(x=df['arrival_time'],palette='pastel')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution Of Flight Arrival Time')


plt.subplot(3,3,5)
ax=sns.countplot(x=df['source_city'],palette='pastel')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution Of Source Cities Of Flight')


plt.subplot(3,3,6)
ax=sns.countplot(x=df['destination_city'],palette='pastel')
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution Of Destination Cities Of Flight')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12144\2861468409.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['stops'],palette='pastel')
# C:\Users\user\AppData\Local\Temp\ipykernel_12144\2861468409.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['departure_time'],palette='pastel')
# C:\Users\user\AppData\Local\Temp\ipykernel_12144\2861468409.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['class'],palette='pastel')
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
#  11  route             300153 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 27.5+ MB

# %%
for col in ['airline', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class']:
    sns.histplot(df[col], bins=20, kde= True, edgecolor='black', color='skyblue')
    plt.title(f'{col} Distribution')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='airline', y='price', data=df)
plt.title('Price Distribution by Airline')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='stops', y='price', data=df)
plt.title('Price Distribution by Stop')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='class', y='price', data=df)
plt.title('Price Distribution by class')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='days_left', y='price', data=df)
plt.title('Price Trend vs Days Before Departure')
plt.gca().invert_xaxis()  
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
for col in numeric_cols:
    sns.histplot(x=col, data=df, kde=True)
    plt.show()
